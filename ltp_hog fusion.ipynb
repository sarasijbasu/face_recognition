# %%
import cv2 as cv2
from matplotlib import pyplot as plt
from PIL import Image
from google.colab.patches import cv2_imshow
import numpy as np

# %%
test_dataset_HOG = "/content/drive/MyDrive/Classroom/orl_HOG/s11_HOG"
test_dataset_LTP = "/content/drive/MyDrive/Classroom/orl_LTP/s11_LTP"

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


images_HOG = []

for img_path in glob.glob(test_dataset_HOG+'/*.pgm'):
    images_HOG.append(cv2.imread(img_path, ))

# %%
images_LTP = []

for img_path in glob.glob(test_dataset_LTP+'/*.pgm'):
    images_LTP.append(cv2.imread(img_path, ))

# %%
for i in range(0,10):
  img1=images_HOG[i]
  cv2_imshow(img1)
  img2=images_LTP[i]
  #img3=images_CLBP[i]
  cv2_imshow(img2)
  dst = cv2.addWeighted(img2,0.5,img1,0.5,0)
  #dst1=cv2.addWeighted(dst,0.7,img2,0.3,0)
  cv2_imshow(dst)
  #cv2.imwrite("/content/drive/MyDrive/Classroom/FUSION/s1/"+str(i)+'.pgm', dst1)
  cv2.imwrite('/content/drive/MyDrive/Classroom/FUSION/s10/'+str(i)+'.pgm', dst)
# Out:
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648DF90>
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648DDD0>
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648DB90>
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648DF10>
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648DF90>
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648DDD0>
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648DB90>
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648DF10>
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648DF90>
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648DDD0>
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648DB90>
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648DF10>
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648DF90>
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648D7D0>
# <PIL.Image.Image image mode=RGB size=92x112 at 0x7F27D648DB90>
# ...
